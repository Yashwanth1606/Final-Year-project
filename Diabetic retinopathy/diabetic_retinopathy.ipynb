# %%
import os
import matplotlib.pyplot as plt 
import cv2 
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
#previewing the images present in the dataset

# %%
#reading and printing the image using cv2 
#the image is printed in the format of an array 
img1=cv2.imread(r'D:\Diabetic retinopathy\Datasets\archive\Healthy\Healthy_4.png')
print(img1)
# Out:
# [[[127 128 127]
#   [131 131 131]
#   [129 128 129]
#   ...
#   [127 127 130]
#   [123 128 123]
#   [124 129 124]]
#
#  [[131 131 131]
#   [124 128 124]
#   [125 124 126]
#   ...
#   [126 127 129]
#   [122 127 122]
#   [123 127 123]]
#
#  [[129 129 129]
#   [125 125 126]
#   [130 122 127]
#   ...
#   [127 125 131]
#   [128 129 127]
#   [128 129 128]]
#
#  ...
#
#  [[134 134 134]
#   [127 127 127]
#   [126 126 126]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[127 127 127]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[128 128 128]
#   [127 127 127]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]]

# %%
#previewing the image using open cv 
plt.imshow(img1)

# %%
#evaluating the size of the image 
print("the shape of the image ")
print(img1.shape)
#so we can see that the image has height=64 px , width=64 px , channel= 3
#so the image is an rgb image
# Out:
# the shape of the image
# (256, 256, 3)

# %%
#converting the rgb image to an grayscale image 
img_gray=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
#checking the shape of the gray image 
print("the shape of the converted image")
img_gray.shape
#here we can see that there is only 64,64 which describes the height and width and there is only one channel
# Out:
# the shape of the converted image
# (256, 256)

# %%
#Checking the array format of the single channel image 
img_gray
# Out:
# array([[128, 131, 128, ..., 128, 126, 127],
#        [131, 126, 125, ..., 127, 125, 125],
#        [129, 125, 124, ..., 127, 128, 129],
#        ...,
#        [134, 127, 126, ..., 128, 128, 128],
#        [127, 128, 128, ..., 128, 128, 128],
#        [128, 127, 128, ..., 128, 128, 128]], dtype=uint8)

# %%
#playing with the colors of the image 
import numpy as np
imgblue=img1[:,:,0]
imggreen=img1[:,:,1]
imgred=img1[:,:,2]
new_image=np.hstack((imgblue,imggreen,imgred))
plt.imshow(new_image)
#so here we can see that since the image does not contain any colors whatever the changes made in the 
#color channel does not reflect on the image

# %%
img = cv2.imread(r'D:\Diabetic retinopathy\Datasets\archive\Mild DR\Mild_DR_2.png', 0)
plt.imshow(img, cmap='gray'), plt.grid(False)
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
hist = cv2.calcHist([img],[0],None,[50],[0,256])

# different methods for displaying a histogram
plt.bar(range(50), hist.ravel())
plt.title('Histogram of the chest xray image')
plt.xlabel('Gray values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import numpy as np
hist,bins = np.histogram(img.ravel(),256,[0,256])
plt.plot(hist)

# %%
from skimage import io
import os
import glob
import numpy as np
import random

DATASET_PATH = r'D:\Diabetic retinopathy\Datasets\archive'
diabetic_cls = ['Healthy', 'Mild DR','Moderate DR','Proliferate DR','Severe DR']


diabetic_path = os.path.join(DATASET_PATH, diabetic_cls[1], '*')
diabetic_path = glob.glob(diabetic_path)
# access some element (a file) from the list
image = io.imread(diabetic_path[251])

# %%
# plotting the original image and the RGB channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
f.set_figwidth(15)
ax1.imshow(image)

# RGB channels
# CHANNELID : 0 for Red, 1 for Green, 2 for Blue. 
ax2.imshow(image[:, : , 0]) #Red
ax3.imshow(image[:, : , 1]) #Green
ax4.imshow(image[:, : , 2]) #Blue
f.suptitle('Different Channels of Image')
# Out:
# Text(0.5, 0.98, 'Different Channels of Image')

# %%
import keras
import tensorflow
from skimage import io
import os
import glob
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to plot n images using subplots
def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image in zip(axes, images):
        ax.imshow(image, cmap)

# %%
# globbing example
# help(glob)
diabetic_path = os.path.join(DATASET_PATH, diabetic_cls[1], '*')
print(diabetic_path)

# glob through the directory (returns a list of all file paths)
diabetic_path = glob.glob(diabetic_path)
print(diabetic_path[3]) # access an individual file
# Out:
# D:\Diabetic retinopathy\Datasets\archive\Mild DR\*
# D:\Diabetic retinopathy\Datasets\archive\Mild DR\Mild_DR_101.png

# %%
# run this block multiple times to look at some randomly chosen images of roses
rand_index = random.randint(0, len(diabetic_path))
image = io.imread(diabetic_path[rand_index])
plt.imshow(image)

# %%
# plot a sample image
diabetic_path = os.path.join(DATASET_PATH, diabetic_cls[1], '*')
diabetic_path = glob.glob(diabetic_path)

# access some element (a file) from the list
#image = io.imread(autism_path[54])
image = io.imread(diabetic_path[54])
plt.imshow(image)

# %%
# plotting the original image and the RGB channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
f.set_figwidth(15)
ax1.imshow(image)

# RGB channels
# CHANNELID : 0 for Red, 1 for Green, 2 for Blue. 
ax2.imshow(image[:, : , 0]) #Red
ax3.imshow(image[:, : , 1]) #Green
ax4.imshow(image[:, : , 2]) #Blue
f.suptitle('Different Channels of Image')
# Out:
# Text(0.5, 0.98, 'Different Channels of Image')

# %%
# bin_image will be a (240, 320) True/False array
#The range of pixel varies between 0 to 255
#The pixel having black is more close to 0 and pixel which is white is more close to 255
# 125 is Arbitrary heuristic measure halfway between 1 and 255 (the range of image pixel) 
bin_image = image[:, :, 0] > 150
plot_image([image, bin_image], cmap='gray')

# %%
from skimage.morphology import binary_closing, binary_dilation, binary_erosion, binary_opening
from skimage.morphology import selem

# use a disk of radius 3
selem = selem.disk(3)

# oprning and closing
open_img = binary_opening(bin_image, selem)
close_img = binary_closing(bin_image, selem)

# erosion and dilation
eroded_img = binary_erosion(bin_image, selem)
dilated_img = binary_dilation(bin_image, selem)

plot_image([bin_image, open_img, close_img, eroded_img, dilated_img], cmap='gray')

# %%
#way1-this is common technique followed in case of RGB images 
norm1_image = image/255
#way2-in case of medical Images/non natural images 
norm2_image = image - np.min(image)/np.max(image) - np.min(image)
#way3-in case of medical Images/non natural images 
norm3_image = image - np.percentile(image,5)/ np.percentile(image,95) - np.percentile(image,5)

plot_image([image, norm1_image, norm2_image, norm3_image], cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from skimage import transform as tf

# flip left-right, up-down
image_flipr = np.fliplr(image)
image_flipud = np.flipud(image)

plot_image([image, image_flipr, image_flipud])

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers

# %%
images_dir = r"D:\Diabetic retinopathy\Datasets\archive"

# %%
batch_size = 32
img_height = 256
img_width = 256

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2750 files belonging to 5 classes.
# Using 2200 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2750 files belonging to 5 classes.
# Using 550 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Healthy', 'Mild DR', 'Moderate DR', 'Proliferate DR', 'Severe DR']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 256, 256, 3)
# (32,)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 5

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 8,412,965
# Trainable params: 8,412,965
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 69/69 [==============================] - 116s 2s/step - loss: 1.0711 - accuracy: 0.5959 - val_loss: 0.9534 - val_accuracy: 0.6109
# Epoch 2/25
# 69/69 [==============================] - 108s 2s/step - loss: 0.8861 - accuracy: 0.6627 - val_loss: 0.9352 - val_accuracy: 0.6327
# Epoch 3/25
# 69/69 [==============================] - 102s 1s/step - loss: 0.8407 - accuracy: 0.6936 - val_loss: 0.9040 - val_accuracy: 0.6509
# Epoch 4/25
# 69/69 [==============================] - 100s 1s/step - loss: 0.8003 - accuracy: 0.6955 - val_loss: 0.8697 - val_accuracy: 0.6745
# Epoch 5/25
# 69/69 [==============================] - 101s 1s/step - loss: 0.7620 - accuracy: 0.7086 - val_loss: 0.9021 - val_accuracy: 0.6673
# Epoch 6/25
# 69/69 [==============================] - 100s 1s/step - loss: 0.6722 - accuracy: 0.7427 - val_loss: 0.8830 - val_accuracy: 0.6673
# Epoch 7/25
# 69/69 [==============================] - 99s 1s/step - loss: 0.5728 - accuracy: 0.7755 - val_loss: 0.9524 - val_accuracy: 0.6873
# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("diabetic_Retina.h5")

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
model1 = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='softmax'),
  layers.Dense(num_classes)
])

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 5
history = model1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %%
import numpy as np
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    images_dir, # Put your path here
     target_size=(img_width, img_height),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 2750 images belonging to 5 classes.
# <ipython-input-46-fedc9fe99a91>:10: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
#        Healthy       0.97      0.98      0.98      1000
#        Mild DR       0.91      0.86      0.88       370
#    Moderate DR       0.88      0.95      0.92       900
# Proliferate DR       0.91      0.80      0.85       290
#      Severe DR       0.91      0.81      0.86       190
#
#       accuracy                           0.92      2750
#      macro avg       0.92      0.88      0.90      2750
#   weighted avg       0.92      0.92      0.92      2750

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(true_classes, predicted_classes)

# %%
test_data = r"D:\Diabetic retinopathy\Datasets\archive\Severe DR\Severe DR_5.png"
test_data_path = test_data

img = keras.preprocessing.image.load_img(
    test_data_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {}"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# This image most likely belongs to Severe DR

# %%
test_data = r"D:\Diabetic retinopathy\DR web\Dataset\Severe_DR_5.png"
test_data_path = test_data

img = keras.preprocessing.image.load_img(
    test_data_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {}"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-76ea82845abe> in <module>
#       2 test_data_path = test_data
#       3
# ----> 4 img = keras.preprocessing.image.load_img(
#       5     test_data_path, target_size=(img_height, img_width)
#       6 )
#
# ~\anaconda3\lib\site-packages\keras\utils\image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Diabetic retinopathy\\DR web\\Dataset\\Severe_DR_5.png'
